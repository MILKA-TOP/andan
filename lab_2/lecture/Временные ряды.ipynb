# %% [markdown]
# # Приведение к стационарному виду

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in d:\anaconda3\envs\lab_2\lib\site-packages (0.1.79)
# Requirement already satisfied: lxml>=4.5.1 in d:\anaconda3\envs\lab_2\lib\site-packages (from yfinance) (4.9.1)
# Requirement already satisfied: pandas>=0.24.0 in d:\anaconda3\envs\lab_2\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: numpy>=1.15 in d:\anaconda3\envs\lab_2\lib\site-packages (from yfinance) (1.23.3)
# Requirement already satisfied: appdirs>=1.4.4 in d:\anaconda3\envs\lab_2\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: requests>=2.26 in d:\anaconda3\envs\lab_2\lib\site-packages (from yfinance) (2.28.1)
# Requirement already satisfied: multitasking>=0.0.7 in d:\anaconda3\envs\lab_2\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: python-dateutil>=2.8.1 in d:\anaconda3\envs\lab_2\lib\site-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda3\envs\lab_2\lib\site-packages (from pandas>=0.24.0->yfinance) (2022.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda3\envs\lab_2\lib\site-packages (from requests>=2.26->yfinance) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda3\envs\lab_2\lib\site-packages (from requests>=2.26->yfinance) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda3\envs\lab_2\lib\site-packages (from requests>=2.26->yfinance) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\anaconda3\envs\lab_2\lib\site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: six>=1.5 in d:\anaconda3\envs\lab_2\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.24.0->yfinance) (1.16.0)

# %%
import yfinance as yf

# %%
df = yf.download('AAPL', '2007-01-01', '2021-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2007-01-03 00:00:00-05:00    3.081786    3.092143    2.925000    2.992857
# 2007-01-04 00:00:00-05:00    3.001786    3.069643    2.993571    3.059286
# 2007-01-05 00:00:00-05:00    3.063214    3.078571    3.014286    3.037500
# 2007-01-08 00:00:00-05:00    3.070000    3.090357    3.045714    3.052500
# 2007-01-09 00:00:00-05:00    3.087500    3.320714    3.041071    3.306071
# ...                               ...         ...         ...         ...
# 2020-12-24 00:00:00-05:00  131.320007  133.460007  131.100006  131.970001
# 2020-12-28 00:00:00-05:00  133.990005  137.339996  133.509995  136.690002
# 2020-12-29 00:00:00-05:00  138.050003  138.789993  134.339996  134.869995
# 2020-12-30 00:00:00-05:00  135.580002  135.990005  133.399994  133.720001
# 2020-12-31 00:00:00-05:00  134.080002  134.740005  131.720001  132.690002
#
#                             Adj Close      Volume
# Date
# 2007-01-03 00:00:00-05:00    2.555397  1238319600
# 2007-01-04 00:00:00-05:00    2.612115   847260400
# 2007-01-05 00:00:00-05:00    2.593513   834741600
# 2007-01-08 00:00:00-05:00    2.606321   797106800
# 2007-01-09 00:00:00-05:00    2.822829  3349298400
# ...                               ...         ...
# 2020-12-24 00:00:00-05:00  130.620911    54930100
# 2020-12-28 00:00:00-05:00  135.292664   124486200
# 2020-12-29 00:00:00-05:00  133.491257   121047300
# 2020-12-30 00:00:00-05:00  132.353027    96452100
# 2020-12-31 00:00:00-05:00  131.333557    99116600
#
# [3525 rows x 6 columns]

# %%
df.Close.plot(figsize=(10, 8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
import numpy as np
np.log(df['Close']).plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df[:2000].describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean     12.099457    12.220210    11.961902    12.094394    10.481052
# std       7.007148     7.054623     6.954797     7.005319     6.201896
# min       2.835357     2.928571     2.792857     2.792857     2.384630
# 25%       5.834643     5.930357     5.698660     5.816964     4.966708
# 50%      11.497500    11.561964    11.396607    11.480714     9.802601
# 75%      18.307946    18.516518    18.138035    18.365000    15.957450
# max      29.817499    29.937500    29.512501    29.750000    26.823727
#
#              Volume
# count  2.000000e+03
# mean   6.233903e+08
# std    3.942956e+08
# min    9.156720e+07
# 25%    3.525256e+08
# 50%    5.114844e+08
# 75%    7.955892e+08
# max    3.372970e+09

# %%
df[2000:].describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1525.000000  1525.000000  1525.000000  1525.000000  1525.000000
# mean     47.902318    48.416728    47.402500    47.931348    46.081509
# std      25.050499    25.430559    24.638054    25.050498    25.355743
# min      22.500000    22.917500    22.367500    22.584999    20.949608
# 25%      29.545000    29.825001    29.334999    29.662500    27.328846
# 50%      40.972500    41.537498    40.602501    41.000000    39.127098
# 75%      53.709999    54.487499    53.152500    53.762501    52.009899
# max     138.050003   138.789993   134.339996   136.690002   135.292664
#
#              Volume
# count  1.525000e+03
# mean   1.462888e+08
# std    7.155367e+07
# min    4.544800e+07
# 25%    9.765440e+07
# 50%    1.281680e+08
# 75%    1.762184e+08
# max    6.488252e+08

# %%
df.Close.hist()
# Out:
# <AxesSubplot:>

# %%
(df['Close']/df['Close'].shift(1)).hist()
# Out:
# <AxesSubplot:>

# %%
import pandas as pd

df.index = pd.to_datetime(df.index)

# %%
df = df.asfreq('1d')[-100:]
df.fillna(method='ffill', inplace=True)
df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2020-09-23 00:00:00-04:00  111.620003  112.110001  106.769997  107.120003
# 2020-09-24 00:00:00-04:00  105.169998  110.250000  105.000000  108.220001
# 2020-09-25 00:00:00-04:00  108.430000  112.440002  107.669998  112.279999
# 2020-09-26 00:00:00-04:00  108.430000  112.440002  107.669998  112.279999
# 2020-09-27 00:00:00-04:00  108.430000  112.440002  107.669998  112.279999
# ...                               ...         ...         ...         ...
# 2020-12-27 00:00:00-05:00  131.320007  133.460007  131.100006  131.970001
# 2020-12-28 00:00:00-05:00  133.990005  137.339996  133.509995  136.690002
# 2020-12-29 00:00:00-05:00  138.050003  138.789993  134.339996  134.869995
# 2020-12-30 00:00:00-05:00  135.580002  135.990005  133.399994  133.720001
# 2020-12-31 00:00:00-05:00  134.080002  134.740005  131.720001  132.690002
#
#                             Adj Close       Volume
# Date
# 2020-09-23 00:00:00-04:00  105.842331  150718700.0
# 2020-09-24 00:00:00-04:00  106.929214  167743300.0
# 2020-09-25 00:00:00-04:00  110.940796  149981400.0
# 2020-09-26 00:00:00-04:00  110.940796  149981400.0
# 2020-09-27 00:00:00-04:00  110.940796  149981400.0
# ...                               ...          ...
# 2020-12-27 00:00:00-05:00  130.620911   54930100.0
# 2020-12-28 00:00:00-05:00  135.292664  124486200.0
# 2020-12-29 00:00:00-05:00  133.491257  121047300.0
# 2020-12-30 00:00:00-05:00  132.353027   96452100.0
# 2020-12-31 00:00:00-05:00  131.333557   99116600.0
#
# [100 rows x 6 columns]

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

result = seasonal_decompose(df['Close'], model='additive')
result.plot()

# %%
import matplotlib.pyplot as plt
from scipy.special import boxcox, inv_boxcox

plt.figure(figsize = (10, 8))
plt.title('Преобразование Бокса-Кокса')
plt.plot(boxcox(df['Close'], -0.1))


#plt.figure(figsize = (10, 8))
plt.plot(df['Close'])

# %%
import matplotlib.pyplot as plt
from scipy.special import boxcox, inv_boxcox

plt.figure(figsize = (10, 8))
plt.title('Обратное преобразование Бокса-Кокса')
plt.plot(inv_boxcox(boxcox(df['Close'], -0.1), -0.1))

# %%
df.asfreq('1 d').fillna(method = 'ffill')['Close'][-100:].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

decomp = seasonal_decompose(df.asfreq('1 d').fillna(method = 'ffill')['Close'][-100:])
plt.plot(decomp.trend)

# %%
plt.plot(decomp.seasonal)

# %%
plt.plot(decomp.resid)

# %%
df['Close'].plot(figsize = (15, 10))
df['Close'].rolling(5).mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
from statsmodels.graphics.tsaplots import plot_acf

plot_acf(df.asfreq('1 d').fillna(method = 'ffill')['Close'][-100:], lags=60)

# %%
import statsmodels.api as sm

test = sm.tsa.adfuller(df.asfreq('1 d').fillna(method = 'ffill')['Close'][-100:])

print('adf', test[0])
print('Critical values', test[4])
# Out:
# adf -1.117389798532307
# Critical values {'1%': -3.4989097606014496, '5%': -2.891516256916761, '10%': -2.5827604414827157}

# %%
def weighted(data, weights):
    res = 0
    for n in range(len(weights)):
        res += data[-n-1] * weights[n]
    return res

# %%
weighted(df['Close'][-3:], [0.2, 0.3, 0.6])
# Out:
# 147.57599792480468

# %%
def exp_smooth(data, alpha):
    res = [data[0]]
    for n in range(1, len(data)):
        res.append(alpha*data[n] + (1-alpha)*res[n-1])
    return res

# %%
plt.plot(df['Close'][-100:].values)
plt.plot(exp_smooth(df['Close'][-100:], 0.4))

# %% [markdown]
# ## Двойное экспоненциальное сглаживание

# %%
def double_exp_smooth(data, alpha, beta):
    res = [data[0]]
    for n in range(1, len(data)):
        if n == 1:
            lev = data[0]
            trend = data[1]-data[0]
        if n>len(data):
            value = res[-1]
        else:
            value = data[n]
        
        last_lev, lev = lev, alpha*value + (1-alpha) * (lev+trend)
        trend = beta*(lev - last_lev) + (1-beta)*trend
        res.append(lev+trend)
    return res

# %%
plt.plot(df['Close'][-100:].values)
plt.plot(double_exp_smooth(df['Close'][-100:], 0.4, 0.6))

# %% [markdown]
# # Модель Хольта-Уинтерса (тройное экспоненциальное сглаживание)

# %% [markdown]
# Экспоненциальное сглаживание часто используется для решения задачи краткосрочного прогнозирования временных рядов.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from scipy.optimize import minimize
from sklearn.metrics import mean_absolute_error, mean_squared_error
import statsmodels.tsa.api as smt

# %% [markdown]
# $\ell_x = \alpha(y_x - s_{x-L}) + (1-\alpha)(\ell_{x-1} + b_{x-1})$
#
# $b_x = \beta(\ell_x - \ell_{x-1}) + (1-\beta)b_{x-1}$
#
# $s_x = \gamma(y_x - \ell_x) + (1-\gamma)s_{x-L}$
#
# $\hat{y}_{x+m} = \ell_x + mb_x + s_{x-L+1+(m-1)modL}$
#
# (В примере выше - аддитивная формула, в вариации мультипликативной $\hat{y}_{x+m} = (\ell_x + mb_x)s_{x-L+1+(m-1)modL}$)
#
# Где:
#
# * $\ell_x $ - level, состовляющая уровня ряда. Является средневзвешенным между текущим значением и предыдущими модельными значениями. Экспоненциальность содержится в использовании предыдущего значения модели и компоненте $1- \alpha$.
# * $b_x$ - trend, состовляющая тренда ряда. Является взвешенным предыдущих изменений ряда.
# * $s_x$ - seasonality, сезонная состовляющая тренда. Определяет колебания вокруг уровня и тренда. Формирует для каждого наблюдения в сезоне создает сезонную компоненту.
# * $\alpha$ - вес, сглаживающий фактор. Физический смысл - важность последнего доступного наблюдения. Чем меньше, тем сильнее происходит сглаживание.
# * $\beta$ - вес, сглаживающий фактор. Аналогично, чем выше - тем сильнее сглаживает тренд.
# * $\gamma$ - вес, сглаживающий фактор. Аналогично, чем выше - тем сильнее сглаживает сезонность.
# * $s_{x-L}$ - коэффициент сезонности за тот же период в предыдущем сезоне.
# * $\ell_{x-1}$ - сглаженная состовляющая ряда на предыдущем периоде.
# * $b_{x-1}$ - значение тренда на предыдущем периоде.
# * $y_x$ - текущее значение ряда (последнее доступное).
# * $\hat{y}_{x+m}$ - предсказываемое значение ряда.
# * $m$ - порядковый номер периода на который делаем прогноз (от последнего текущего)
# * $L$ - длина сезона в периодах
#
# Коэффициенты $\alpha, \beta, \gamma$ минимизируются в соответсвии с MSE.
#
# Число $L$ определяется в зависимости от количества сезонов. Ее можно определить визуально, например, недельная сезонность, $L = 7$. Или дневная сезонность $L = 24$. Сезонности могут быть комбинированными - т.е. и дневная и недельная (и любая другая, зависит от вашего типа данных), тогда $L = 24*7$ сезонных компонент. Выбор нужного значения может быть нетривиальной проблемой т.е. данные могут иметь любую комбинацию значений (и шумов), трендов и сезонности. Возможно, у него даже нет некоторых из этих компонентов. Обычно они неизвестны, если вы не проверяете данные вручную и не настраиваете для них модель.
#
# О сезонности:
# (Источник Молодежный научно-технический вестник ФС77-51038, ISSN 2307-0609)
#
# Сезонная компонента имеет аддитивную природу в случае, когда с заранее
# известным периодом в исходном ряду проявляются достаточно постоянные
# периодические отклонения в абсолютном выражении от варьирующегося во времени
# среднего уровня ряда. Например, если в июле каждого года предприятие продает на
# 100.000 единиц больше продукции, чем в другие месяцы года в среднем. Таким образом,
# мы могли бы добавить к нашим прогнозам на июль 100.000 единиц, чтобы учесть эти
# сезонные колебания.
#
# Если сезонные отклонения от варьирующегося во времени среднего уровня ряда
# носят характер достаточно устойчивого относительного изменения, то сезонность имеет
# мультипликативную природу. Например, если в ноябре каждого года предприятие
# продает на 25% больше продукции, чем в другие месяцы года в среднем. В этом случае
# мы могли бы умножить прогноз на ноябрь на 1,25 (индекс сезонности) и таким образом
# учесть мультипликативные сезонные колебания.

# %% [markdown]
# Проблема выбора оптимальной сезонности, визуализация: (источник https://orangematter.solarwinds.com/2019/12/15/holt-winters-forecasting-simplified/)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Подбор параметров можно произвести с помощью минимизации MSE, изначально ограничив диапазон поиска (например сглаживающие коэффициенты на 0-1). Например, можно взять метод Truncated Newton conjugate gradient или метод [Nelder-Mead](https://orangematter.solarwinds.com/2018/03/12/numeric-optimization-in-golang-with-nelder-mead-and-gonum/)

# %% [markdown]
# При обоих видах сезонности начальное значение уровня $s_0$ представляется целесообразным установить равным среднему арифметическому первого сезона:
#
# $$s_0 = \sum_{t=1}^L Y_t/L$$
#
# Начальное значение компонента тренда может быть установлен (при обоих видах
# сезонности) как в формуле ниже:
#
# $$b_0 = \frac{1}{L} \left(
# \frac{y_{L+1} - y_1}{L} + \frac{y_{L+2} - y_2}{L} + \cdots + \frac{y_{L+L} - y_L}{L}
# \right) \, .$$
#
# Наконец, начальное значение индекса сезонности можно рассчитать с помощью
# одного из следующих уравнений в зависимости от природы сезонности:
#
# * $c_0 = Y_i - S_0, \forall i = 1, 2, \dots , L$ в аддитивном случае
# * $c_0 = \frac{Y_i}{S_0}, \forall i = 1, 2, \dots , L$ в мультипликативном случае

# %%
import pandas as pd
df = pd.read_csv('https://dl.uploadgram.me/6213cb751cec3h?raw', index_col=['Date'], parse_dates=['Date'])

# %%
df.head()
# Out:
#                        ads
# Date
# 2017-08-03 00:00:00  49136
# 2017-08-03 01:00:00  46450
# 2017-08-03 02:00:00  46355
# 2017-08-03 03:00:00  43748
# 2017-08-03 04:00:00  42281

# %%
df.plot()
df.rolling(50).mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
def HolterWinter(data, L, alpha, beta, gamma, m):
    # находим изначальные сезонности
    season_num = int(len(data)/L)# кол-во cезонов
    seasonalities = {} # сами сезонности
    season_avgs = [] # их среднее
    # находим сезонное среднее
    season_avgs = [sum(data[L*i: L*i+L])/float(L) for i in range(season_num)]
    # находим начальные значения cезонности
    for i in range(L):
        avg_over_summ = 0.0
        for j in range(season_num):
            avg_over_summ += data[L*j+i] - season_avgs[j]
        seasonalities[i] = avg_over_summ / season_num
    # инициализируем массивы результирующих прогнозов, сгалженных, сезонных и трендовых (нужны в формулах на пред шагах)
    result = []
    smooth = []
    season = []
    trend = []
    # пройдемся по всем данным + длинна предсказания m
    for i in range(len(data) + m):
        # инициализируем значения шага 0
        if i==0:
            smooth_val = data[0] # первое значения сглаживания
            trend_val = sum([(float(data[i+L] - data[i]) / L) for i in range(L)]) / L # первое значения тренда
            result.append(data[0]) # первая точка данных совпадает с исходной
            smooth.append(smooth_val) # добавляем первое значение сглаживание в массив трендов
            trend.append(trend_val) # добавляем первое значение тренда в массив трендов
            season.append(seasonalities[i%L]) # см mod L
            continue # завершаем первый шаг
        # выполняем прогноз, если вышли за пределы данных
        if i >= len(data):
            # текущее прогнозируемое значение t+1, t+2, ... (текущее m)
            curr_m = i - len(data) + 1
            result.append((smooth_val + curr_m*trend_val) + seasonalities[i%L])
        else: # основной цикл вычисления параметров
            last_smooth_val = smooth_val
            smooth_val = alpha*(data[i] - seasonalities[i%L]) + (1 - alpha)*(smooth_val + trend_val) # обновляем lx
            trend_val = beta * (smooth_val - last_smooth_val) + trend_val*(1 - beta) # обновляем bx
            seasonalities[i%L] = gamma * (data[i] - smooth_val) + (1 - gamma)*seasonalities[i%L] # обновляем sx
            result.append(smooth_val + trend_val + seasonalities[i%L]) # записываем результат

            smooth.append(smooth_val)
            trend.append(trend_val)
            season.append(seasonalities[i%L])
    return result[-m:]

# %%
from sklearn.model_selection import TimeSeriesSplit

def timeseriesCVscore(w):
    # вектор ошибок
    errors = []
    values = data.values
    alpha, beta, gamma = w
    
    # задаём число фолдов для кросс-валидации
    tscv = TimeSeriesSplit(n_splits=3) 
    
    # идем по фолдам кросс-валидации, на каждом обучаем модель, строим прогноз на отложенной выборке и считаем ошибку
    for train, test in tscv.split(values):
        # тут preds - все сглаженное + предсказания (т.е. надо обрезать под размер теста - [-len(test):])
        preds = HolterWinter(data=values[train], L = 24*7, alpha=alpha, beta=beta, gamma=gamma, m=len(test))
        error = mean_squared_error(preds[-len(test):], values[test])
        # print(error, alpha, beta, gamma)
        errors.append(error)
    # возвращаем усреднение
    return np.mean(np.array(errors))

# %%
from scipy.optimize import minimize
from sklearn.metrics import mean_squared_error

# %%
# %%time
data = df['ads'][:-128] # отложим часть данных для тестирования
# Минимизируем функцию потерь с ограничениями на параметры
# альтернативные method = L-BFGS-B, TNC, SLSQP, Powell, trust-constr
optimizer = minimize(timeseriesCVscore, x0=[0, 0, 0], method="L-BFGS-B", bounds = ((0, 1), (0, 1), (0, 1)))

# Из оптимизатора берем оптимальное значение параметров
alpha, beta, gamma = optimizer.x
print(alpha, beta, gamma)
# Out:
# 0.01566079303709085 0.0015031568400184273 0.2249782679653761
# CPU times: total: 1.31 s
# Wall time: 1.34 s

# %%
import time
# замеряем скорости сходимости оптимизаторов
for optimizer in ['L-BFGS-B', 'TNC', 'SLSQP', 'Powell', 'trust-constr']:
    try:
        start = time.time()
        print('\nОптимизатор:', optimizer, end=' ')
        data = df['ads'][:-128] # отложим часть данных для тестирования
        # Минимизируем функцию потерь с ограничениями на параметры
        optimizer = minimize(timeseriesCVscore, x0=[0, 0, 0], method=optimizer, bounds = ((0, 1), (0, 1), (0, 1)))

        # Из оптимизатора берем оптимальное значение параметров
        alpha, beta, gamma = optimizer.x
        print('\nalpha, beta, gamma:', alpha, beta, gamma)

        end = time.time()
        print('Скорость сходимости (сек)', round(end - start, 2))
    except:
        # часть из них почему-то выдает ошибки из-за ошибок кодирования
        pass
# Out:
# Оптимизатор: L-BFGS-B
# alpha, beta, gamma: 0.01566079303709085 0.0015031568400184273 0.2249782679653761
# Скорость сходимости (сек) 1.49
#
# Оптимизатор: TNC
# alpha, beta, gamma: 0.01566146044180511 0.0015031782180036646 0.22496953556600136
# Скорость сходимости (сек) 4.29
#
# Оптимизатор: SLSQP
# alpha, beta, gamma: 0.0 0.0 0.0
# Скорость сходимости (сек) 0.04
#
# Оптимизатор: Powell
# alpha, beta, gamma: 0.01739741082630847 0.7134169926395064 4.492746266658951e-05
# Скорость сходимости (сек) 0.53
#
# Оптимизатор: trust-constr
# D:\anaconda3\envs\lab_2\lib\site-packages\scipy\optimize\_hessian_update_strategy.py:182: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   warn('delta_grad == 0.0. Check if the approximated '
# alpha, beta, gamma: 0.01566103740732938 0.0015031478240444937 0.22497133292881724
# Скорость сходимости (сек) 9.49

# %% [markdown]
# Самый быстрый оказался SLSQP

# %%
df['ads'].values[:-128]
# Out:
# array([49136, 46450, 46355, ..., 71807, 71959, 74223], dtype=int64)

# %%
preds = HolterWinter(data=df['ads'].values[:-128], L = 24*7, alpha=alpha, beta=beta, gamma=gamma, m=128)

# %%
mean_squared_error(df['ads'].values[-128:], preds[-128:]) # абсолютные значения достаточно велики
# Out:
# 75803295.62213224

# %%
plt.figure(figsize=(30, 12))
plt.plot(preds, label = "Предсказанное")
plt.plot(df['ads'].values, label = "Реальное")
# зона предсказания
plt.axvspan(len(df['ads'])-128, len(df['ads']), alpha=0.5, color='lightgrey')
plt.grid(True)
plt.axis('tight')
plt.legend(loc="best", fontsize=18);

# %% [markdown]
# Перебор различных значений сезонностей

# %%
errors_per_L = []
params_per_L = []

# %%
from tqdm import tqdm

for i in tqdm(range(1, 200)):
    data = df['ads'][:-128] # отложим часть данных для тестирования
    # Минимизируем функцию потерь с ограничениями на параметры
    # альтернативные method = L-BFGS-B, TNC, SLSQP, Powell, trust-constr
    optimizer = minimize(timeseriesCVscore, x0=[0, 0, 0], method="L-BFGS-B", bounds = ((0, 1), (0, 1), (0, 1)))
    # Из оптимизатора берем оптимальное значение параметров
    alpha, beta, gamma = optimizer.x
    preds = HolterWinter(data=df['ads'].values[:-128], L = 24*7, alpha=alpha, beta=beta, gamma=gamma, m=128)
    errors_per_L.append(mean_squared_error(df['ads'].values[-128:], preds[-128:]))
    params_per_L.append(optimizer.x)
    # print(alpha, beta, gamma)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [44], in <cell line: 1>()
# ----> 1 from tqdm import tqdm
#       3 for i in tqdm(range(1, 200)):
#       4     data = df['ads'][:-128] # отложим часть данных для тестирования
#
# ModuleNotFoundError: No module named 'tqdm'

# %%
np.where(errors_per_L == min(errors_per_L))

# %%
alpha, beta, gamma = params_per_L[137]

# %%
fig, ax = plt.subplots(figsize=(16, 10))
smt.graphics.plot_acf(df['ads'], lags=1000, ax=ax)

# %%
fig, ax = plt.subplots(figsize=(16, 10))
smt.graphics.plot_pacf(df['ads'], lags=500, ax=ax)

# %% [markdown]
# В модель включен метод Брутлага для построения доверительных интервалов:
#
# $\hat y_{max_x}=\ell_{x−1}+b_{x−1}+s_{x−T}+m⋅d_{t−T}$
#
# $\hat y_{min_x}=\ell_{x−1}+b_{x−1}+s_{x−T}-m⋅d_{t−T}$
#
# $d_t=\gamma∣y_t−\hat y_t∣+(1−\gamma)d_{t−T}$,
#
# Где
#
# * $T$ - длина сезона
# * $d$ - предсказанное отклонение
#
# [тык](https://fedcsis.org/proceedings/2012/pliks/118.pdf)

# %%
def HolterWinter_bounds(data, L, alpha, beta, gamma, m, scale):
    # находим изначальные сезонности
    season_num = int(len(data)/L)# кол-во cезонов
    seasonalities = {} # сами сезонности
    season_avgs = [] # их среднее
    # находим сезонное среднее
    season_avgs = [sum(data[L*i: L*i+L])/float(L) for i in range(season_num)]
    # находим начальные значения cезонности
    for i in range(L):
        avg_over_summ = 0.0
        for j in range(season_num):
            avg_over_summ += data[L*j+i] - season_avgs[j]
        seasonalities[i] = avg_over_summ / season_num
    # инициализируем массивы результирующих прогнозов, сгалженных, сезонных и трендовых (нужны в формулах на пред шагах)
    result = []
    smooth = []
    season = []
    trend = []
    deviation = []
    upper_bound = []
    lower_bound = []
    # пройдемся по всем данным + длинна предсказания m
    for i in range(len(data) + m):
        # инициализируем значения шага 0
        if i==0:
            smooth_val = data[0] # первое значения сглаживания
            trend_val = sum([(float(data[i+L] - data[i]) / L) for i in range(L)]) / L # первое значения тренда
            result.append(data[0]) # первая точка данных совпадает с исходной
            smooth.append(smooth_val) # добавляем первое значение сглаживание в массив трендов
            trend.append(trend_val) # добавляем первое значение тренда в массив трендов
            season.append(seasonalities[i%L]) # см mod L
            deviation.append(0)
            upper_bound.append(result[0] + scale*deviation[0])
            lower_bound.append(result[0] - scale*deviation[0])
            continue # завершаем первый шаг
        # выполняем прогноз, если вышли за пределы данных
        if i >= len(data):
            # текущее прогнозируемое значение t+1, t+2, ... (текущее m)
            curr_m = i - len(data) + 1
            result.append((smooth_val + curr_m*trend_val) + seasonalities[i%L])
            # в предсказаниях доверительный интервал будет расходиться
            deviation.append(1.01 * deviation[-1]) 
        else: # основной цикл вычисления параметров
            last_smooth_val = smooth_val
            smooth_val = alpha*(data[i] - seasonalities[i%L]) + (1 - alpha)*(smooth_val + trend_val) # обновляем lx
            trend_val = beta * (smooth_val - last_smooth_val) + trend_val*(1 - beta) # обновляем bx
            seasonalities[i%L] = gamma * (data[i] - smooth_val) + (1 - gamma)*seasonalities[i%L] # обновляем sx
            result.append(smooth_val + trend_val + seasonalities[i%L]) # записываем результат

            smooth.append(smooth_val)
            trend.append(trend_val)
            season.append(seasonalities[i%L])
            deviation.append(gamma*abs(data[i] - result[i]) + (1-gamma)*deviation[-1])
            # print(abs(data[i] - result[i])*gamma)
        # добавим доверительный интервал
        upper_bound.append(result[-1] + scale*deviation[-1]) 
        lower_bound.append(result[-1] - scale*deviation[-1])

    return result, upper_bound, lower_bound, deviation

# %%
from sklearn.model_selection import TimeSeriesSplit

def timeseriesCVscore(w):
    # вектор ошибок
    errors = []
    values = data.values
    alpha, beta, gamma = w
    
    # задаём число фолдов для кросс-валидации
    tscv = TimeSeriesSplit(n_splits=3) 
    
    # идем по фолдам кросс-валидации, на каждом обучаем модель, строим прогноз на отложенной выборке и считаем ошибку
    for train, test in tscv.split(values):
        # тут preds - все сглаженное + предсказания (т.е. надо обрезать под размер теста - [-len(test):])
        preds, upper, lower, deviation = HolterWinter_bounds(data=values[train], L = 24*7, alpha=alpha, beta=beta, gamma=gamma, m=len(test), scale= 1.9)
        error = mean_squared_error(preds[-len(test):], values[test])
        # print(error, alpha, beta, gamma)
        errors.append(error)
    # возвращаем усреднение
    return np.mean(np.array(errors))

# %%
# %%time
data = df['ads'][:-128] # отложим часть данных для тестирования
# Минимизируем функцию потерь с ограничениями на параметры
# альтернативные method = L-BFGS-B, TNC, SLSQP, Powell, trust-constr
optimizer = minimize(timeseriesCVscore, x0=[0, 0, 0], method="L-BFGS-B", bounds = ((0, 1), (0, 1), (0, 1)))

# Из оптимизатора берем оптимальное значение параметров
alpha, beta, gamma = optimizer.x
print(alpha, beta, gamma)

# %%
optimizer.x

# %%
preds, upper, lower, deviation = HolterWinter_bounds(data=df['ads'].values[:-128], L = 24*7, alpha=alpha, beta=beta, gamma=gamma, m=128, scale= 1.9)

# %%
len(deviation)

# %%
len(preds)

# %%
pd.Series(deviation).plot(figsize=(10, 7))

# %%
plt.figure(figsize=(30, 12))
plt.plot(preds, label = "Предсказанное")
plt.plot(df['ads'].values, label = "Реальное")

# plt.plot(upper, "r--", alpha=0.5, label = "Верхний доверительный интервал")
# plt.plot(lower, "r--", alpha=0.5, label = "Нижний доверительный интервал")
plt.fill_between(x=range(0,len(df['ads'])), y1=lower, y2=upper, alpha=0.5, color = "blue")

# зона предсказания
plt.axvspan(len(df['ads'])-128, len(df['ads']), alpha=0.5, color='lightgrey')
plt.grid(True)
plt.axis('tight')
plt.legend(loc="best", fontsize=18);
plt.xlim(1800, 2200)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\anaconda3\envs\lab_2\lib\site-packages\pandas\core\indexes\base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File D:\anaconda3\envs\lab_2\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File D:\anaconda3\envs\lab_2\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ads'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [59], in <cell line: 3>()
#       1 plt.figure(figsize=(30, 12))
#       2 plt.plot(preds, label = "Предсказанное")
# ----> 3 plt.plot(df['ads'].values, label = "Реальное")
#       5 # plt.plot(upper, "r--", alpha=0.5, label = "Верхний доверительный интервал")
#       6 # plt.plot(lower, "r--", alpha=0.5, label = "Нижний доверительный интервал")
#       7 plt.fill_between(x=range(0,len(df['ads'])), y1=lower, y2=upper, alpha=0.5, color = "blue")
#
# File D:\anaconda3\envs\lab_2\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File D:\anaconda3\envs\lab_2\lib\site-packages\pandas\core\indexes\base.py:3631, in Index.get_loc(self, key, method, tolerance)
#    3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
# -> 3631     raise KeyError(key) from err
#    3632 except TypeError:
#    3633     # If we have a listlike key, _check_indexing_error will raise
#    3634     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3635     #  the TypeError.
#    3636     self._check_indexing_error(key)
#
# KeyError: 'ads'

# %% [markdown]
# # SARIMA

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/a10.csv', parse_dates=['date'], index_col='date')
df.head()
df.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df
# Out:
#                 value
# date
# 1991-07-01   3.526591
# 1991-08-01   3.180891
# 1991-09-01   3.252221
# 1991-10-01   3.611003
# 1991-11-01   3.565869
# ...               ...
# 2008-02-01  21.654285
# 2008-03-01  18.264945
# 2008-04-01  23.107677
# 2008-05-01  22.912510
# 2008-06-01  19.431740
#
# [204 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(boxcox(df['value'], -0.2))

# %%
from scipy.special import boxcox, inv_boxcox

plt.plot(inv_boxcox(boxcox(df['value'], -0.2), -0.2))

# %%
df['value'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
boxcox(df['value'], -0.2).diff(2).diff(3).plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
#!pip install statsmodels
# !pip install pmdarima
# Out:
# Requirement already satisfied: pmdarima in d:\anaconda3\envs\lab_2\lib\site-packages (1.8.5)
# Requirement already satisfied: joblib>=0.11 in d:\anaconda3\envs\lab_2\lib\site-packages (from pmdarima) (1.1.1)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in d:\anaconda3\envs\lab_2\lib\site-packages (from pmdarima) (63.4.1)
# Requirement already satisfied: scipy>=1.3.2 in d:\anaconda3\envs\lab_2\lib\site-packages (from pmdarima) (1.9.1)
# Requirement already satisfied: pandas>=0.19 in d:\anaconda3\envs\lab_2\lib\site-packages (from pmdarima) (1.4.4)
# Requirement already satisfied: statsmodels!=0.12.0,>=0.11 in d:\anaconda3\envs\lab_2\lib\site-packages (from pmdarima) (0.13.2)
# Requirement already satisfied: urllib3 in d:\anaconda3\envs\lab_2\lib\site-packages (from pmdarima) (1.26.12)
# Requirement already satisfied: scikit-learn>=0.22 in d:\anaconda3\envs\lab_2\lib\site-packages (from pmdarima) (1.1.2)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in d:\anaconda3\envs\lab_2\lib\site-packages (from pmdarima) (0.29.32)
# Requirement already satisfied: numpy>=1.19.3 in d:\anaconda3\envs\lab_2\lib\site-packages (from pmdarima) (1.23.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in d:\anaconda3\envs\lab_2\lib\site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda3\envs\lab_2\lib\site-packages (from pandas>=0.19->pmdarima) (2022.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\anaconda3\envs\lab_2\lib\site-packages (from scikit-learn>=0.22->pmdarima) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in d:\anaconda3\envs\lab_2\lib\site-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (0.5.2)
# Requirement already satisfied: packaging>=21.3 in d:\anaconda3\envs\lab_2\lib\site-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\anaconda3\envs\lab_2\lib\site-packages (from packaging>=21.3->statsmodels!=0.12.0,>=0.11->pmdarima) (3.0.9)
# Requirement already satisfied: six in d:\anaconda3\envs\lab_2\lib\site-packages (from patsy>=0.5.2->statsmodels!=0.12.0,>=0.11->pmdarima) (1.16.0)

# %%
from pmdarima.arima import auto_arima

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df[:].diff(12).plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
len(df)
# Out:
# 204

# %%
model = auto_arima(boxcox(df['value'][:180], -0.2), start_p=0, start_q=0, test='adf', max_d=4, max_q=4, m=12,
           start_P=0, seasonal=True, error_action ='ignore', supress_warnings=True, trace=True)

model.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,1)[12] intercept   : AIC=inf, Time=0.22 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=121.742, Time=0.03 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=inf, Time=0.38 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=inf, Time=0.18 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=710.223, Time=0.01 sec
#  ARIMA(0,0,0)(1,0,0)[12] intercept   : AIC=inf, Time=0.24 sec
#  ARIMA(0,0,0)(1,0,1)[12] intercept   : AIC=-377.690, Time=0.35 sec
#  ARIMA(0,0,0)(2,0,1)[12] intercept   : AIC=inf, Time=0.67 sec
#  ARIMA(0,0,0)(1,0,2)[12] intercept   : AIC=-401.164, Time=0.74 sec
#  ARIMA(0,0,0)(0,0,2)[12] intercept   : AIC=inf, Time=0.45 sec
#  ARIMA(0,0,0)(2,0,2)[12] intercept   : AIC=-426.617, Time=0.91 sec
#  ARIMA(1,0,0)(2,0,2)[12] intercept   : AIC=-536.418, Time=0.98 sec
#  ARIMA(1,0,0)(1,0,2)[12] intercept   : AIC=-551.237, Time=0.90 sec
#  ARIMA(1,0,0)(0,0,2)[12] intercept   : AIC=-456.143, Time=0.45 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : AIC=-539.601, Time=0.36 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : AIC=-381.621, Time=0.18 sec
#  ARIMA(1,0,0)(2,0,1)[12] intercept   : AIC=-537.387, Time=0.88 sec
#  ARIMA(2,0,0)(1,0,2)[12] intercept   : AIC=-603.441, Time=0.90 sec
#  ARIMA(2,0,0)(0,0,2)[12] intercept   : AIC=-479.432, Time=0.68 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : AIC=-590.224, Time=0.39 sec
#  ARIMA(2,0,0)(2,0,2)[12] intercept   : AIC=inf, Time=1.01 sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : AIC=-400.140, Time=0.29 sec
#  ARIMA(2,0,0)(2,0,1)[12] intercept   : AIC=-584.003, Time=0.99 sec
#  ARIMA(3,0,0)(1,0,2)[12] intercept   : AIC=-620.061, Time=0.98 sec
#  ARIMA(3,0,0)(0,0,2)[12] intercept   : AIC=-482.124, Time=0.78 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : AIC=-614.174, Time=0.48 sec
#  ARIMA(3,0,0)(2,0,2)[12] intercept   : AIC=inf, Time=1.27 sec
#  ARIMA(3,0,0)(0,0,1)[12] intercept   : AIC=-403.319, Time=0.39 sec
#  ARIMA(3,0,0)(2,0,1)[12] intercept   : AIC=-599.618, Time=1.24 sec
#  ARIMA(4,0,0)(1,0,2)[12] intercept   : AIC=-617.460, Time=1.01 sec
#  ARIMA(3,0,1)(1,0,2)[12] intercept   : AIC=-594.972, Time=1.08 sec
#  ARIMA(2,0,1)(1,0,2)[12] intercept   : AIC=-604.541, Time=0.94 sec
#  ARIMA(4,0,1)(1,0,2)[12] intercept   : AIC=-604.479, Time=1.29 sec
#  ARIMA(3,0,0)(1,0,2)[12]             : AIC=-622.649, Time=0.85 sec
#  ARIMA(3,0,0)(0,0,2)[12]             : AIC=inf, Time=0.74 sec
#  ARIMA(3,0,0)(1,0,1)[12]             : AIC=-615.468, Time=0.43 sec
#  ARIMA(3,0,0)(2,0,2)[12]             : AIC=inf, Time=1.10 sec
#  ARIMA(3,0,0)(0,0,1)[12]             : AIC=inf, Time=0.30 sec
#  ARIMA(3,0,0)(2,0,1)[12]             : AIC=-599.590, Time=0.92 sec
#  ARIMA(2,0,0)(1,0,2)[12]             : AIC=-604.338, Time=0.78 sec
#  ARIMA(4,0,0)(1,0,2)[12]             : AIC=-619.912, Time=0.99 sec
#  ARIMA(3,0,1)(1,0,2)[12]             : AIC=-604.648, Time=0.98 sec
#  ARIMA(2,0,1)(1,0,2)[12]             : AIC=-622.828, Time=0.83 sec
#  ARIMA(2,0,1)(0,0,2)[12]             : AIC=-472.311, Time=0.87 sec
#  ARIMA(2,0,1)(1,0,1)[12]             : AIC=-609.332, Time=0.41 sec
#  ARIMA(2,0,1)(2,0,2)[12]             : AIC=inf, Time=1.16 sec
#  ARIMA(2,0,1)(0,0,1)[12]             : AIC=inf, Time=0.39 sec
#  ARIMA(2,0,1)(2,0,1)[12]             : AIC=-588.173, Time=0.91 sec
#  ARIMA(1,0,1)(1,0,2)[12]             : AIC=-628.708, Time=0.85 sec
#  ARIMA(1,0,1)(0,0,2)[12]             : AIC=inf, Time=0.55 sec
#  ARIMA(1,0,1)(1,0,1)[12]             : AIC=-618.981, Time=0.36 sec
#  ARIMA(1,0,1)(2,0,2)[12]             : AIC=inf, Time=0.98 sec
#  ARIMA(1,0,1)(0,0,1)[12]             : AIC=inf, Time=0.25 sec
#  ARIMA(1,0,1)(2,0,1)[12]             : AIC=inf, Time=0.86 sec
#  ARIMA(0,0,1)(1,0,2)[12]             : AIC=-422.536, Time=0.64 sec
#  ARIMA(1,0,0)(1,0,2)[12]             : AIC=-554.304, Time=0.72 sec
#  ARIMA(1,0,2)(1,0,2)[12]             : AIC=-627.862, Time=0.98 sec
#  ARIMA(0,0,0)(1,0,2)[12]             : AIC=-374.920, Time=0.73 sec
#  ARIMA(0,0,2)(1,0,2)[12]             : AIC=-459.010, Time=0.87 sec
#  ARIMA(2,0,2)(1,0,2)[12]             : AIC=inf, Time=1.68 sec
#  ARIMA(1,0,1)(1,0,2)[12] intercept   : AIC=-609.465, Time=1.10 sec
#
# Best model:  ARIMA(1,0,1)(1,0,2)[12]
# Total fit time: 43.868 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                         SARIMAX Results
# ===============================================================================================
# Dep. Variable:                                       y   No. Observations:                  180
# Model:             SARIMAX(1, 0, 1)x(1, 0, [1, 2], 12)   Log Likelihood                 320.354
# Date:                                 Mon, 24 Oct 2022   AIC                           -628.708
# Time:                                         16:34:01   BIC                           -609.551
# Sample:                                              0   HQIC                          -620.941
#                                                  - 180
# Covariance Type:                                   opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9964      0.003    357.942      0.000       0.991       1.002
# ma.L1         -0.7194      0.058    -12.425      0.000      -0.833      -0.606
# ar.S.L12       0.9948      0.003    308.734      0.000       0.988       1.001
# ma.S.L12      -0.3636      0.079     -4.594      0.000      -0.519      -0.208
# ma.S.L24      -0.2895      0.089     -3.254      0.001      -0.464      -0.115
# sigma2         0.0013      0.000     10.920      0.000       0.001       0.002
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.64   Jarque-Bera (JB):                10.79
# Prob(Q):                              0.42   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.55   Skew:                            -0.24
# Prob(H) (two-sided):                  0.02   Kurtosis:                         4.10
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
fitted, confint = model.predict(n_periods=24, return_conf_int=True)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 10))
plt.plot(df)
idx = pd.date_range(df.index[-24], periods=24, freq='MS')
print(idx)
plt.plot(pd.Series(fitted, index=idx))
plt.fill_between(idx, confint[:, 0], confint[:, 1], alpha=.15)
# Out:
# DatetimeIndex(['2017-11-01 21:00:00', '2017-12-01 21:00:00',
#                '2018-01-01 21:00:00', '2018-02-01 21:00:00',
#                '2018-03-01 21:00:00', '2018-04-01 21:00:00',
#                '2018-05-01 21:00:00', '2018-06-01 21:00:00',
#                '2018-07-01 21:00:00', '2018-08-01 21:00:00',
#                '2018-09-01 21:00:00', '2018-10-01 21:00:00',
#                '2018-11-01 21:00:00', '2018-12-01 21:00:00',
#                '2019-01-01 21:00:00', '2019-02-01 21:00:00',
#                '2019-03-01 21:00:00', '2019-04-01 21:00:00',
#                '2019-05-01 21:00:00', '2019-06-01 21:00:00',
#                '2019-07-01 21:00:00', '2019-08-01 21:00:00',
#                '2019-09-01 21:00:00', '2019-10-01 21:00:00'],
#               dtype='datetime64[ns]', freq='MS')
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [45], in <cell line: 6>()
#       4 idx = pd.date_range(df.index[-24], periods=24, freq='MS')
#       5 print(idx)
# ----> 6 plt.plot(pd.Series(fitted, index=idx))
#       7 plt.fill_between(idx, confint[:, 0], confint[:, 1], alpha=.15)
#
# NameError: name 'fitted' is not defined

# %%
from sklearn.metrics import mean_absolute_percentage_error

mean_absolute_percentage_error(df.value.values[-24:], fitted)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 10))
plt.plot(df)
idx = pd.date_range(df.index[-24], periods=24, freq='MS')
print(pd.Series(inv_boxcox(fitted, -0.2), index=idx))
plt.plot(pd.Series(inv_boxcox(fitted, -0.2), index=idx))
# plt.fill_between(idx, confint[:, 0], confint[:, 1], alpha=.15)

# %%
mean_absolute_percentage_error(df.value.values[-24:], inv_boxcox(fitted, -0.2))
